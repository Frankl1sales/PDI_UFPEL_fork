# %% [markdown]
# <a href="https://colab.research.google.com/github/MFerrugem/PDI_UFPEL/blob/main/aula_05_b.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
from skimage import io, util, filters

# Carregar imagem
I = io.imread('images/eight.tif')
I = I.astype(float) / 255.0  # Normalizar para [0, 1]

# Adicionar ruídos
Isp = util.random_noise(I, mode='s&p', amount=0.03)
Ig = util.random_noise(I, mode='gaussian', var=0.024)

# Aplicar filtro de mediana
Im = filters.median(I)
Isp_m = filters.median(Isp)
Ig_m = filters.median(Ig)

# %%
# Plotar imagens
plt.figure(figsize=(15,5))

plt.subplot(1,3,1)
plt.imshow(Im, cmap='gray')
plt.title('Imagem Original Filtrada')
plt.axis('off')

plt.subplot(1,3,2)
plt.imshow(Isp_m, cmap='gray')
plt.title('Ruído Sal e Pimenta Filtrado')
plt.axis('off')

plt.subplot(1,3,3)
plt.imshow(Ig_m, cmap='gray')
plt.title('Ruído Gaussiano Filtrado')
plt.axis('off')

plt.tight_layout()
plt.show()
