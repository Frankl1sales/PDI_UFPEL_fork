# %% [markdown]
# <a href="https://colab.research.google.com/github/MFerrugem/PDI_UFPEL/blob/main/aula_5_a.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Importando os modulos
import numpy as np
import matplotlib.pyplot as plt
from skimage import io, util,filters
from scipy.ndimage import convolve

# %%
# Carregar a imagem
I = io.imread('images/eight.tif')

# %%
# Criar figura com  3 subplots
plt.figure(figsize=(15,5))

# Imagem Original
plt.subplot(1,3,1)
plt.imshow(I, cmap='gray')
plt.title('Imagem Original')
# Out:
# Text(0.5, 1.0, 'Imagem Original')

# %%
# Ruido sal e pimente /salt & pepper noise (3%)
Isp = util.random_noise(I, mode='s&p', amount=0.03)

# Imagem com ruído sal e pimenta
plt.subplot(1,3,2)
plt.imshow(Isp, cmap='gray')
plt.title('Salt & Pepper Noise')
# Out:
# Text(0.5, 1.0, 'Salt & Pepper Noise')

# %%
# Ruido gaussiano (variancia 0.02)
Ig = util.random_noise(I, mode='gaussian', var=0.02)

# Imagem com ruído gaussiando
plt.subplot(1,3,3)
plt.imshow(Ig, cmap='gray')
plt.title('Gaussian Noise')
# Out:
# Text(0.5, 1.0, 'Gaussian Noise')

# %%
plt.subplot(1,3,1)
plt.imshow(I, cmap='gray')
plt.title('Imagem Original')
# Imagem com ruído sal e pimenta
plt.subplot(1,3,2)
plt.imshow(Isp, cmap='gray')
plt.title('Salt & Pepper Noise')

# Imagem com ruído gaussiando
plt.subplot(1,3,3)
plt.imshow(Ig, cmap='gray')
plt.title('Gaussian Noise')

# Show the plot
plt.tight_layout()
plt.show()

# %%
# Criar kernel de média
k = np.ones((3, 3)) / 9.0


# Aplicar filtro de média (scikit-image) - https://scikit-image.org/docs/0.24.x/auto_examples/filters/index.html
# Aplicar filtro de média (scipy)
Im = convolve(I, k)
Isp_m = convolve(Isp, k)
Ig_m = convolve(Ig, k)

# Plotar imagens
plt.figure(figsize=(15,5))

plt.subplot(1,3,1)
plt.imshow(Im, cmap='gray')
plt.title('Imagem Original Filtrada')
plt.axis('off')

plt.subplot(1,3,2)
plt.imshow(Isp_m, cmap='gray')
plt.title('Ruído Sal e Pimenta Filtrado')
plt.axis('off')

plt.subplot(1,3,3)
plt.imshow(Ig_m, cmap='gray')
plt.title('Ruído Gaussiano Filtrado')
plt.axis('off')

plt.tight_layout()
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.ndimage import convolve
from skimage import data, img_as_float
from skimage.util import random_noise

# C

# Adicionar ruído sal e pimenta
Isp = random_noise(I, mode='s&p')

# Adicionar ruído gaussiano
Ig = random_noise(I, mode='gaussian')


# Criar kernel de média 3x3
k = np.ones((3, 3)) / 9.0

# Aplicar filtro de média
Im = convolve(I, k)
Isp_m = convolve(Isp, k)
Ig_m = convolve(Ig, k)




# Plotar imagens
plt.figure(figsize=(15,5))

plt.subplot(1,3,1)
plt.imshow(Im, cmap='gray')
plt.title('Imagem Original Filtrada')
plt.axis('off')

plt.subplot(1,3,2)
plt.imshow(Isp_m, cmap='gray')
plt.title('Ruído Sal e Pimenta Filtrado')
plt.axis('off')

plt.subplot(1,3,3)
plt.imshow(Ig_m, cmap='gray')
plt.title('Ruído Gaussiano Filtrado')
plt.axis('off')

plt.tight_layout()
plt.show()
